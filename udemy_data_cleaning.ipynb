# %%
import pandas as pd

# %%
data = pd.read_csv("udemy_data.csv")
data.head()
# Out:
#    Unnamed: 0                URL from a Topic on Udemy  Max Courses  \
# 0         NaN  https://www.udemy.com/topic/javascript/          120
# 1         NaN  https://www.udemy.com/topic/javascript/          120
# 2         NaN  https://www.udemy.com/topic/javascript/          120
# 3         NaN  https://www.udemy.com/topic/javascript/          120
# 4         NaN  https://www.udemy.com/topic/javascript/          120
#
#    Max Related Topics  Position  \
# 0                   5         1
# 1                   5         2
# 2                   5         3
# 3                   5         4
# 4                   5         5
#
#                                         Course Title  \
# 0  The Complete JavaScript Course 2024: From Zero...
# 1  JavaScript: Understanding the Weird Parts\nAn ...
# 2  JavaScript Basics for Beginners\nJavaScript - ...
# 3  Modern JavaScript From The Beginning 2.0 (2024...
# 4  JavaScript - The Complete Guide 2024 (Beginner...
#
# ...

# %%
df = data.drop(['URL from a Topic on Udemy', 'Max Courses', 
                'Max Related Topics', 'Position', 'Price', 
                'Instructor', 'Number of Lectures'], axis=1)

# %%
df.head()
# Out:
#    Unnamed: 0                                       Course Title  \
# 0         NaN  The Complete JavaScript Course 2024: From Zero...
# 1         NaN  JavaScript: Understanding the Weird Parts\nAn ...
# 2         NaN  JavaScript Basics for Beginners\nJavaScript - ...
# 3         NaN  Modern JavaScript From The Beginning 2.0 (2024...
# 4         NaN  JavaScript - The Complete Guide 2024 (Beginner...
#
#                                          Course Link  \
# 0  https://www.udemy.com/course/the-complete-java...
# 1  https://www.udemy.com/course/understand-javasc...
# 2  https://www.udemy.com/course/javascript-basics...
# 3  https://www.udemy.com/course/modern-javascript...
# 4  https://www.udemy.com/course/javascript-the-co...
#
#                                          Description  Rating  \
# 0  The modern JavaScript course for everyone! Mas...     4.7
# 1  An advanced JavaScript course for everyone! Sc...     4.7
# 2    JavaScript - Master the Fundamentals in 6 Hours     4.6
# ...

# %%
len(df)
# Out:
# 140

# %%
final_df = df.iloc[:49]

# %%
data = final_df.drop(['Unnamed: 0'], axis=1)

# %%
len(data)
# Out:
# 49

# %%
data.to_csv("out_udemy.csv", index=False)

# %%
d1 = pd.read_csv("out_udemy.csv")
d1.head()
# Out:
#                                         Course Title  \
# 0  The Complete JavaScript Course 2024: From Zero...
# 1  JavaScript: Understanding the Weird Parts\nAn ...
# 2  JavaScript Basics for Beginners\nJavaScript - ...
# 3  Modern JavaScript From The Beginning 2.0 (2024...
# 4  JavaScript - The Complete Guide 2024 (Beginner...
#
#                                          Course Link  \
# 0  https://www.udemy.com/course/the-complete-java...
# 1  https://www.udemy.com/course/understand-javasc...
# 2  https://www.udemy.com/course/javascript-basics...
# 3  https://www.udemy.com/course/modern-javascript...
# 4  https://www.udemy.com/course/javascript-the-co...
#
#                                          Description  Rating  \
# 0  The modern JavaScript course for everyone! Mas...     4.7
# 1  An advanced JavaScript course for everyone! Sc...     4.7
# 2    JavaScript - Master the Fundamentals in 6 Hours     4.6
# 3  A 36-hour master course to take you from begin...     4.7
# ...

# %%
output2 = pd.read_csv("output02.csv")
output2.head()
# Out:
#                                               Course  \
# 0  The Complete Python Bootcamp From Zero to Hero...
# 1  The Complete 2024 Web Development BootcampBeco...
# 2  100 Days of Code: The Complete Python Pro Boot...
# 3                                 Try Udemy Business
# 4  The Web Developer Bootcamp 202410 Hours of Rea...
#
#                                                 Link  \
# 0  https://www.udemy.com/course/complete-python-b...
# 1  https://www.udemy.com/course/the-complete-web-...
# 2     https://www.udemy.com/course/100-days-of-code/
# 3  https://www.udemy.com/udemy-business/request-d...
# 4  https://www.udemy.com/course/the-web-developer...
#
#                                          Course Name  total hours  rating  \
# 0  The Complete Python Bootcamp From Zero to Hero...         22.0     4.6
# 1         The Complete 2024 Web Development Bootcamp         61.5     4.7
# 2  100 Days of Code: The Complete Python Pro Boot...         58.5     4.7
# ...

# %%
final_output = output2.drop(['Course'], axis=1)

# %%
final_output.to_csv("final_output02.csv", index=False)

# %%
data = pd.read_excel('udemy_data.xlsx')
data.head()
# Out:
#    Unnamed: 0                URL from a Topic on Udemy  Max Courses  \
# 0         NaN  https://www.udemy.com/topic/javascript/          120
# 1         NaN  https://www.udemy.com/topic/javascript/          120
# 2         NaN  https://www.udemy.com/topic/javascript/          120
# 3         NaN  https://www.udemy.com/topic/javascript/          120
# 4         NaN  https://www.udemy.com/topic/javascript/          120
#
#    Max Related Topics  Position  \
# 0                   5         1
# 1                   5         2
# 2                   5         3
# 3                   5         4
# 4                   5         5
#
#                                         Course Title  \
# 0  The Complete JavaScript Course 2024: From Zero...
# 1  JavaScript: Understanding the Weird Parts\nAn ...
# 2  JavaScript Basics for Beginners\nJavaScript - ...
# 3  Modern JavaScript From The Beginning 2.0 (2024...
# 4  JavaScript - The Complete Guide 2024 (Beginner...
#
# ...

# %%
df = data.drop(['URL from a Topic on Udemy', 'Max Courses', 
                'Max Related Topics', 'Position', 'Price', 
                'Instructor', 'Number of Lectures'], axis=1)

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.to_excel('udemy_excel.xlsx', index=False)

# %%
df = pd.read_excel('udemy_excel.xlsx')

# %%
final_df = df.iloc[:49]

# %%
final_df.to_excel('udemy_excel_50.xlsx', index=False)
